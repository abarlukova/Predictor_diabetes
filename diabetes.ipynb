# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.feature_extraction import DictVectorizer

from sklearn.metrics import roc_auc_score

from sklearn.model_selection import KFold

# %%
df_init = pd.read_csv("data/diabetes.csv")

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
print("len(df_init) = ", len(df_init))
# Out:
# len(df_init) =  768

# %% [markdown]
# #### Check missing values

# %%
print(df_init.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print("Outcome unique values : ", df_init.Outcome.unique())
# Out:
# Outcome unique values :  [1 0]

# %% [markdown]
# #### Check global diabetes rate

# %%
df_init.Outcome.value_counts(normalize=True)
# Out:
# Outcome
# 0    0.651042
# 1    0.348958
# Name: proportion, dtype: float64

# %% [markdown]
# #### Check data types

# %%
print(df_init.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# There is no categorical values

# %%
# Create a summary DataFrame with max, min, and mean
summary = pd.DataFrame({
    'Min': df_init.min(),
    'Max': df_init.max(),
    'Mean': df_init.mean(),
    'Median': df_init.median()
})

print("Min, Max, Mean and Median values for each column:")
print(summary)
# Out:
# Min, Max, Mean and Median values for each column:
#                              Min     Max        Mean    Median
# Pregnancies                0.000   17.00    3.845052    3.0000
# Glucose                    0.000  199.00  120.894531  117.0000
# BloodPressure              0.000  122.00   69.105469   72.0000
# SkinThickness              0.000   99.00   20.536458   23.0000
# Insulin                    0.000  846.00   79.799479   30.5000
# BMI                        0.000   67.10   31.992578   32.0000
# DiabetesPedigreeFunction   0.078    2.42    0.471876    0.3725
# Age                       21.000   81.00   33.240885   29.0000
# Outcome                    0.000    1.00    0.348958    0.0000

# %% [markdown]
# ### Feature importance

# %%
df_init[df_init["Pregnancies"] > 3].Outcome.mean()
# Out:
# 0.45058139534883723

# %% [markdown]
# Number of pregnancies are important

# %%
df_init[df_init["Age"] > 40].Outcome.mean()
# Out:
# 0.5257731958762887

# %% [markdown]
# Age is highly important

# %%
df_init[df_init["Glucose"] > 117].Outcome.mean()
# Out:
# 0.5411140583554377

# %% [markdown]
# Glucose level is highly important

# %%
df_init[df_init["Insulin"] > 30.5].Outcome.mean()
# Out:
# 0.3333333333333333

# %% [markdown]
# Insulin is not important

# %%
df_init[df_init["BMI"] > 32].Outcome.mean()
# Out:
# 0.468586387434555

# %% [markdown]
# Body mass index is important

# %%
df_init[df_init["DiabetesPedigreeFunction"] > 0.3725].Outcome.mean()
# Out:
# 0.4036458333333333

# %% [markdown]
# DiabetesPedigreeFunction is important

# %%
df_init[df_init["BloodPressure"] > 72].Outcome.mean()
# Out:
# 0.40974212034383956

# %% [markdown]
# BloodPressure is important

# %% [markdown]
# #### Correlations

# %%
df_init.corrwith(df_init.Outcome).sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# dtype: float64

# %% [markdown]
# The most important features are __Glucose__, __BMI__, __Age__, and __Pregnancies__

# %% [markdown]
# ### Data preparation

# %% [markdown]
# #### lowercase, and adding underscore between words

# %%
def add_underscore(string):
    l_newstr = []
    for letters in string:
        if letters.isupper():
            letters = "_"+letters
        l_newstr.append(letters)
    newstr = ''.join(l_newstr)

    if newstr.startswith('_'):
        newstr = newstr[1:]
    return newstr

df_init.rename(columns=lambda col: add_underscore(col), inplace=True)

df_init.columns = df_init.columns.str.lower()

df_init.rename(columns={"b_m_i": "bmi"}, inplace=True)

print(df_init.columns)
# Out:
# Index(['pregnancies', 'glucose', 'blood_pressure', 'skin_thickness', 'insulin',
#        'bmi', 'diabetes_pedigree_function', 'age', 'outcome'],
#       dtype='object')

# %%
df_init.head().T
# Out:
#                                   0       1        2       3        4
# pregnancies                   6.000   1.000    8.000   1.000    0.000
# glucose                     148.000  85.000  183.000  89.000  137.000
# blood_pressure               72.000  66.000   64.000  66.000   40.000
# skin_thickness               35.000  29.000    0.000  23.000   35.000
# insulin                       0.000   0.000    0.000  94.000  168.000
# bmi                          33.600  26.600   23.300  28.100   43.100
# diabetes_pedigree_function    0.627   0.351    0.672   0.167    2.288
# age                          50.000  31.000   32.000  21.000   33.000
# outcome                       1.000   0.000    1.000   0.000    1.000

# %% [markdown]
# ### Split data

# %% [markdown]
# Do train/validation/test split with 60%/20%/20% distribution.
#
# Use the train_test_split function and set the random_state parameter to 42.

# %%
df_full_train, df_test = train_test_split(df_init, test_size = 0.2, random_state = 42)

# %%
len(df_full_train), len(df_test)
# Out:
# (614, 154)

# %%
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state = 42)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (460, 154, 154)

# %%
df_train.head()
# Out:
#      pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 335            0      165              76              43      255  47.9
# 467            0       97              64              36      100  36.8
# 51             1      101              50              15       36  24.2
# 131            9      122              56               0        0  33.3
# 649            0      107              60              25        0  26.4
#
#      diabetes_pedigree_function  age  outcome
# 335                       0.259   26        0
# 467                       0.600   25        0
# 51                        0.526   26        0
# 131                       1.114   33        1
# 649                       0.133   23        0

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.outcome.values
y_val = df_val.outcome.values
y_test = df_test.outcome.values

# %%
del df_train["outcome"]
del df_val["outcome"]
del df_test["outcome"]

# %%
df_full_train.head()
# Out:
#      pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 60             2       84               0               0        0   0.0
# 618            9      112              82              24        0  28.2
# 346            1      139              46              19       83  28.7
# 294            0      161              50               0        0  21.9
# 231            6      134              80              37      370  46.2
#
#      diabetes_pedigree_function  age  outcome
# 60                        0.304   21        0
# 618                       1.282   50        1
# 346                       0.654   22        0
# 294                       0.254   65        0
# 231                       0.238   46        1

# %%
y_full_train = df_full_train.outcome.values

# %%
del df_full_train["outcome"]

# %% [markdown]
# ### Logistic regression

# %%
def train(df_train, y_train, C=10):
    dicts = df_train.to_dict(orient='records')

    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(dicts)

    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000, random_state=42)
    #model = LogisticRegression(C=C, max_iter=1000, random_state=42)

    model.fit(X_train, y_train)
    
    return dv, model

# %%
def predict(df, dv, model):
    dicts = df.to_dict(orient='records')

    X = dv.transform(dicts)
    y_pred = model.predict_proba(X)[:, 1]

    return y_pred

# %%
n_splits = 5

# %%
len(y_train)
# Out:
# 460

# %%
len(df_train)
# Out:
# 491

# %%
C=10

# %%
kfold = KFold(n_splits=n_splits, shuffle=True, random_state=1)

scores = []

for train_idx, val_idx in kfold.split(df_full_train):
    df_train = df_full_train.iloc[train_idx]
    df_val = df_full_train.iloc[val_idx]

    y_train = df_train.outcome.values
    y_val = df_val.outcome.values

    del df_train["outcome"]
    del df_val["outcome"]

    dv, model = train(df_train, y_train, C=10)
    y_pred = predict(df_val, dv, model)

    auc = roc_auc_score(y_val, y_pred)
    scores.append(auc)

print('C=%s %.3f +- %.3f' % (C, np.mean(scores), np.std(scores)))
# Out:
# C=10 0.831 +- 0.027

# %%
scores
# Out:
# [0.8089359200470312,
#  0.84622248661511,
#  0.7980599647266313,
#  0.827710843373494,
#  0.8727477477477478]

# %%
dv, model = train(df_full_train, y_full_train)
y_pred = predict(df_test, dv, model)

auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.8159779614325069

# %% [markdown]
# ### Save the model

# %%
import pickle

# %%
output_file = f'model_C=10.bin'

# %%
f_out = open(output_file, 'wb') 
pickle.dump((dv, model), f_out)
f_out.close()

# %%
input_file = f'model_C=10.bin'

# %%
with open(input_file, 'rb') as f_in: 
    dv, model = pickle.load(f_in)

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
dicts_train = df_train.to_dict(orient='records')

# %%
X_train = dv.fit_transform(dicts_train)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
dicts_val = df_val.to_dict(orient='records')
X_val = dv.transform(dicts_val)

# %%
y_pred_val = model.predict_proba(X_val)[:, 1]

# %%
#diabetes_prediction = (y_pred >= 0.5)

# %%
#(y_val == diabetes_prediction.astype(int)).mean()
# Out:
# 0.7532467532467533

# %%
auc_pred_val = roc_auc_score(y_val, y_pred_val)
print(f'AUC for y_pred_val: {round(auc_pred_val,3)}')
# Out:
# AUC for y_pred_val: 0.84

# %% [markdown]
# ### Using the model

# %%
model_c_10 = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)

# %%
dicts_full_train = df_full_train.to_dict(orient='records')

# %%
X_full_train = dv.fit_transform(dicts_full_train)

# %%
model_c_10.fit(X_full_train, y_full_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
dicts_test = df_test.to_dict(orient='records')
X_test = dv.transform(dicts_test)

# %%
y_pred_test = model_c_10.predict_proba(X_test)[:, 1]

# %%
auc_pred_test = roc_auc_score(y_test, y_pred_test)
print(f'AUC for y_pred_test: {round(auc_pred_test,3)}')
# Out:
# AUC for y_pred_test: 0.816

# %%
c_arr = [0.01, 0.1, 1, 10, 100]

for c in c_arr:
    print('c=',c)
    model = LogisticRegression(solver='liblinear', C=c, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)
    y_pred_val_c = model.predict_proba(X_val)[:, 1]

    auc_pred_val_c = roc_auc_score(y_val, y_pred_val_c)
    print(f'AUC for y_pred_val: {round(auc_pred_val_c,3)}')
    print('----------------')
# Out:
# c= 0.01
# AUC for y_pred_val: 0.618
# ----------------
# c= 0.1
# AUC for y_pred_val: 0.705
# ----------------
# c= 1
# AUC for y_pred_val: 0.84
# ----------------
# c= 10
# AUC for y_pred_val: 0.86
# ----------------
# c= 100
# AUC for y_pred_val: 0.862
# ----------------

# %% [markdown]
# ### Transform to dict

# %%
trial_participant = dicts_test[11]

# %%
X_small = dv.transform([trial_participant])

# %%
trial_participant
# Out:
# {'pregnancies': 10,
#  'glucose': 111,
#  'blood_pressure': 70,
#  'skin_thickness': 27,
#  'insulin': 0,
#  'bmi': 27.5,
#  'diabetes_pedigree_function': 0.141,
#  'age': 40}

# %%
model.predict_proba(pd.DataFrame(X_small)).round(3)[0,1]
# Out:
# 0.265

# %%
model.predict(pd.DataFrame(X_small))[0]
# Out:
# 0

# %%
y_test[10]
# Out:
# 1

# %% [markdown]
# ### Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=4, random_state=1, n_jobs=-1)

# %%
rf.fit(df_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=4, n_jobs=-1, random_state=1)

# %%
y_pred_val_rf = rf.predict(df_val)

# %%
auc_pred_val_rf = roc_auc_score(y_val, y_pred_val_rf)
print(f'AUC for y_pred_val_rf: {round(auc_pred_val_rf,3)}')
# Out:
# AUC for y_pred_val_rf: 0.744

# %%
for estim in range(2, 50, 1):
    print(f"estim = {estim}")
    rf = RandomForestRegressor(n_estimators=estim, random_state=1, n_jobs=-1)
    rf.fit(df_train, y_train)
    y_pred_val_rf = rf.predict(df_val)
    auc_pred_val_rf = roc_auc_score(y_val, y_pred_val_rf)
    print(f'AUC for y_pred_val_rf: {round(auc_pred_val_rf,3)}')
    print("------------------------")
# Out:
# estim = 2
# AUC for y_pred_val_rf: 0.732
# ------------------------
# estim = 3
# AUC for y_pred_val_rf: 0.738
# ------------------------
# estim = 4
# AUC for y_pred_val_rf: 0.744
# ------------------------
# estim = 5
# AUC for y_pred_val_rf: 0.747
# ------------------------
# estim = 6
# AUC for y_pred_val_rf: 0.748
# ------------------------
# estim = 7
# AUC for y_pred_val_rf: 0.763
# ------------------------
# estim = 8
# AUC for y_pred_val_rf: 0.78
# ------------------------
# estim = 9
# AUC for y_pred_val_rf: 0.791
# ------------------------
# estim = 10
# AUC for y_pred_val_rf: 0.809
# ------------------------
# estim = 11
# AUC for y_pred_val_rf: 0.819
# ------------------------
# estim = 12
# AUC for y_pred_val_rf: 0.816
# ------------------------
# estim = 13
# AUC for y_pred_val_rf: 0.821
# ------------------------
# estim = 14
# AUC for y_pred_val_rf: 0.826
# ------------------------
# estim = 15
# AUC for y_pred_val_rf: 0.826
# ------------------------
# estim = 16
# AUC for y_pred_val_rf: 0.821
# ------------------------
# estim = 17
# AUC for y_pred_val_rf: 0.812
# ------------------------
# estim = 18
# AUC for y_pred_val_rf: 0.811
# ------------------------
# estim = 19
# AUC for y_pred_val_rf: 0.811
# ------------------------
# estim = 20
# AUC for y_pred_val_rf: 0.813
# ------------------------
# estim = 21
# AUC for y_pred_val_rf: 0.816
# ------------------------
# estim = 22
# AUC for y_pred_val_rf: 0.817
# ------------------------
# estim = 23
# AUC for y_pred_val_rf: 0.816
# ------------------------
# estim = 24
# AUC for y_pred_val_rf: 0.819
# ------------------------
# estim = 25
# AUC for y_pred_val_rf: 0.821
# ------------------------
# estim = 26
# AUC for y_pred_val_rf: 0.826
# ------------------------
# estim = 27
# AUC for y_pred_val_rf: 0.83
# ------------------------
# estim = 28
# AUC for y_pred_val_rf: 0.828
# ------------------------
# estim = 29
# AUC for y_pred_val_rf: 0.829
# ------------------------
# estim = 30
# AUC for y_pred_val_rf: 0.828
# ------------------------
# estim = 31
# AUC for y_pred_val_rf: 0.829
# ------------------------
# estim = 32
# AUC for y_pred_val_rf: 0.828
# ------------------------
# estim = 33
# AUC for y_pred_val_rf: 0.83
# ------------------------
# estim = 34
# AUC for y_pred_val_rf: 0.832
# ------------------------
# estim = 35
# AUC for y_pred_val_rf: 0.837
# ------------------------
# estim = 36
# AUC for y_pred_val_rf: 0.839
# ------------------------
# estim = 37
# AUC for y_pred_val_rf: 0.836
# ------------------------
# estim = 38
# AUC for y_pred_val_rf: 0.834
# ------------------------
# estim = 39
# AUC for y_pred_val_rf: 0.837
# ------------------------
# estim = 40
# AUC for y_pred_val_rf: 0.839
# ------------------------
# estim = 41
# AUC for y_pred_val_rf: 0.839
# ------------------------
# estim = 42
# AUC for y_pred_val_rf: 0.835
# ------------------------
# estim = 43
# AUC for y_pred_val_rf: 0.834
# ------------------------
# estim = 44
# AUC for y_pred_val_rf: 0.834
# ------------------------
# estim = 45
# AUC for y_pred_val_rf: 0.833
# ------------------------
# estim = 46
# AUC for y_pred_val_rf: 0.832
# ------------------------
# estim = 47
# AUC for y_pred_val_rf: 0.83
# ------------------------
# estim = 48
# AUC for y_pred_val_rf: 0.83
# ------------------------
# estim = 49
# AUC for y_pred_val_rf: 0.829
# ------------------------

# %%
for md in range(2,10):
    print(f"max_depth = {md}")
    
    
    rmse_curr_md = []
    
    

        
    rf = RandomForestRegressor(n_estimators=10, max_depth = md, random_state=1, n_jobs=-1)
    rf.fit(df_train, y_train)

    y_pred_val_rf = rf.predict(df_val)
    auc_pred_val_rf = roc_auc_score(y_val, y_pred_val_rf)
    print(f'AUC for y_pred_val_rf: {round(auc_pred_val_rf,3)}')
    
    print("------------------------")
# Out:
# max_depth = 2
# AUC for y_pred_val_rf: 0.795
# ------------------------
# max_depth = 3
# AUC for y_pred_val_rf: 0.799
# ------------------------
# max_depth = 4
# AUC for y_pred_val_rf: 0.817
# ------------------------
# max_depth = 5
# AUC for y_pred_val_rf: 0.83
# ------------------------
# max_depth = 6
# AUC for y_pred_val_rf: 0.839
# ------------------------
# max_depth = 7
# AUC for y_pred_val_rf: 0.819
# ------------------------
# max_depth = 8
# AUC for y_pred_val_rf: 0.816
# ------------------------
# max_depth = 9
# AUC for y_pred_val_rf: 0.812
# ------------------------

# %% [markdown]
# ### XGBoost model

# %%
#import xgboost as xgb

from xgboost import XGBClassifier

# %%
model = XGBClassifier(random_state=42)
model.fit(df_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_val_proba = model.predict_proba(df_val)[:, 1]

# %%
# Calculate the ROC AUC score
roc_auc = roc_auc_score(y_val, y_pred_val_proba)

print(f"ROC AUC Score: {roc_auc:.3f}")
# Out:
# ROC AUC Score: 0.817

# %%
#dtrain = xgb.DMatrix(df_train, label=y_train, feature_names = list(df_train.columns.values))

# %%
#dval = xgb.DMatrix(df_val, label=y_val, feature_names = list(df_train.columns.values))

# %%
# xgb_params_1 = {
#         'eta': 0.3, 
#         'max_depth': 6,
#         'min_child_weight': 1,
        
#         'objective': 'binary:logistic',
#         'nthread': 8,
        
#         'seed': 1,
#         'verbosity': 1,
#     }

# %%
#watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
#from matplotlib import pyplot as plt

# %%
# def parse_xgb_output(output):
#     results = []

#     for line in output.stdout.strip().split('\n'):
#         it_line, train_line, val_line = line.split('\t')

#         it = int(it_line.strip('[]'))
#         train = float(train_line.split(':')[1])
#         val = float(val_line.split(':')[1])

#         results.append((it, train, val))
    
#     columns = ['num_iter', 'train_auc', 'val_auc']
#     df_results = pd.DataFrame(results, columns=columns)
#     return df_results

# %%
#%%capture output_1

#model_1 = xgb.train(xgb_params_1, dtrain, evals = watchlist, num_boost_round=100)

#s = output_1.stdout
# Out:
# [0]	train-logloss:0.52554	val-logloss:0.56498
# [1]	train-logloss:0.44785	val-logloss:0.52744
# [2]	train-logloss:0.39008	val-logloss:0.50714
# [3]	train-logloss:0.34831	val-logloss:0.49492
# [4]	train-logloss:0.32249	val-logloss:0.48837
# [5]	train-logloss:0.28906	val-logloss:0.48391
# [6]	train-logloss:0.27461	val-logloss:0.48530
# [7]	train-logloss:0.25150	val-logloss:0.48980
# [8]	train-logloss:0.23646	val-logloss:0.49376
# [9]	train-logloss:0.22351	val-logloss:0.49989
# [10]	train-logloss:0.21495	val-logloss:0.50964
# [11]	train-logloss:0.20336	val-logloss:0.51430
# [12]	train-logloss:0.18999	val-logloss:0.51440
# [13]	train-logloss:0.18070	val-logloss:0.52322
# [14]	train-logloss:0.17207	val-logloss:0.51692
# [15]	train-logloss:0.16332	val-logloss:0.51712
# [16]	train-logloss:0.15680	val-logloss:0.51290
# [17]	train-logloss:0.14830	val-logloss:0.51904
# [18]	train-logloss:0.14139	val-logloss:0.51915
# [19]	train-logloss:0.13579	val-logloss:0.52249
# [20]	train-logloss:0.13171	val-logloss:0.52608
# [21]	train-logloss:0.12208	val-logloss:0.52822
# [22]	train-logloss:0.11812	val-logloss:0.53648
# [23]	train-logloss:0.11359	val-logloss:0.52799
# [24]	train-logloss:0.10763	val-logloss:0.53403
# [25]	train-logloss:0.10443	val-logloss:0.54172
# [26]	train-logloss:0.10046	val-logloss:0.54203
# [27]	train-logloss:0.09766	val-logloss:0.53981
# [28]	train-logloss:0.09295	val-logloss:0.55266
# [29]	train-logloss:0.08990	val-logloss:0.56112
# [30]	train-logloss:0.08754	val-logloss:0.55737
# [31]	train-logloss:0.08484	val-logloss:0.56146
# [32]	train-logloss:0.08162	val-logloss:0.56462
# [33]	train-logloss:0.07879	val-logloss:0.56547
# [34]	train-logloss:0.07636	val-logloss:0.56366
# [35]	train-logloss:0.07353	val-logloss:0.56013
# [36]	train-logloss:0.07264	val-logloss:0.56100
# [37]	train-logloss:0.07101	val-logloss:0.56554
# [38]	train-logloss:0.06833	val-logloss:0.57288
# [39]	train-logloss:0.06607	val-logloss:0.57863
# [40]	train-logloss:0.06480	val-logloss:0.57661
# [41]	train-logloss:0.06337	val-logloss:0.57722
# [42]	train-logloss:0.06126	val-logloss:0.57813
# [43]	train-logloss:0.05973	val-logloss:0.57481
# [44]	train-logloss:0.05814	val-logloss:0.58133
# [45]	train-logloss:0.05730	val-logloss:0.57975
# [46]	train-logloss:0.05577	val-logloss:0.58323
# [47]	train-logloss:0.05432	val-logloss:0.58674
# [48]	train-logloss:0.05355	val-logloss:0.58440
# [49]	train-logloss:0.05226	val-logloss:0.58658
# [50]	train-logloss:0.05128	val-logloss:0.59178
# [51]	train-logloss:0.05008	val-logloss:0.59351
# [52]	train-logloss:0.04879	val-logloss:0.60160
# [53]	train-logloss:0.04803	val-logloss:0.60348
# [54]	train-logloss:0.04701	val-logloss:0.60425
# [55]	train-logloss:0.04609	val-logloss:0.60853
# [56]	train-logloss:0.04509	val-logloss:0.61133
# [57]	train-logloss:0.04440	val-logloss:0.61444
# [58]	train-logloss:0.04369	val-logloss:0.61468
# [59]	train-logloss:0.04291	val-logloss:0.61461
# [60]	train-logloss:0.04207	val-logloss:0.61767
# [61]	train-logloss:0.04136	val-logloss:0.62456
# [62]	train-logloss:0.04076	val-logloss:0.62752
# [63]	train-logloss:0.04021	val-logloss:0.62647
# [64]	train-logloss:0.03956	val-logloss:0.62765
# [65]	train-logloss:0.03900	val-logloss:0.63159
# [66]	train-logloss:0.03846	val-logloss:0.63194
# [67]	train-logloss:0.03779	val-logloss:0.63227
# [68]	train-logloss:0.03715	val-logloss:0.63594
# [69]	train-logloss:0.03691	val-logloss:0.63889
# [70]	train-logloss:0.03638	val-logloss:0.64152
# [71]	train-logloss:0.03590	val-logloss:0.64201
# [72]	train-logloss:0.03537	val-logloss:0.64669
# [73]	train-logloss:0.03497	val-logloss:0.64904
# [74]	train-logloss:0.03460	val-logloss:0.64622
# [75]	train-logloss:0.03417	val-logloss:0.65069
# [76]	train-logloss:0.03384	val-logloss:0.65044
# [77]	train-logloss:0.03353	val-logloss:0.64970
# [78]	train-logloss:0.03305	val-logloss:0.65447
# [79]	train-logloss:0.03266	val-logloss:0.65951
# [80]	train-logloss:0.03227	val-logloss:0.66080
# [81]	train-logloss:0.03178	val-logloss:0.66129
# [82]	train-logloss:0.03137	val-logloss:0.66366
# [83]	train-logloss:0.03114	val-logloss:0.66293
# [84]	train-logloss:0.03077	val-logloss:0.66248
# [85]	train-logloss:0.03044	val-logloss:0.66125
# [86]	train-logloss:0.03013	val-logloss:0.66183
# [87]	train-logloss:0.02977	val-logloss:0.66483
# [88]	train-logloss:0.02952	val-logloss:0.66523
# [89]	train-logloss:0.02926	val-logloss:0.66766
# [90]	train-logloss:0.02902	val-logloss:0.66756
# [91]	train-logloss:0.02875	val-logloss:0.66774
# [92]	train-logloss:0.02849	val-logloss:0.67116
# [93]	train-logloss:0.02828	val-logloss:0.67352
# [94]	train-logloss:0.02799	val-logloss:0.67139
# [95]	train-logloss:0.02771	val-logloss:0.67068
# [96]	train-logloss:0.02742	val-logloss:0.67063
# [97]	train-logloss:0.02722	val-logloss:0.67029
# [98]	train-logloss:0.02701	val-logloss:0.67409
# [99]	train-logloss:0.02680	val-logloss:0.67182

# %%
# df_score = parse_xgb_output(output_1)

# plt.plot(df_score.num_iter, df_score.train_auc, label='train')
# plt.plot(df_score.num_iter, df_score.val_auc, label='val')
# plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22416\242953562.py in ?()
#       1 df_score = parse_xgb_output(output_1)
#       2
# ----> 3 plt.plot(df_score.num_iter, df_score.train_auc, label='train')
#       4 plt.plot(df_score.num_iter, df_score.val_auc, label='val')
#       5 plt.legend()
#
# ~\AppData\Local\anaconda3\envs\ml-zoomcamp\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'train_auc'
